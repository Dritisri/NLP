# %% [markdown]
# <a href="https://colab.research.google.com/github/Dritisri/NLP/blob/main/2403a52236_NLP_ASS_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
import nltk
import spacy

# %%
text="""Artificial Intelligence is the simulation of human intelligence processes by machines, especially computer systems.
It is used in healthcare, education, and transportatiion.
NLP help machine understand human language."""

# %%
words=text.split()
word_count=len(words)
print("Number of words:", word_count)
# Out:
# Number of words: 28

# %%
lowercase_text = text.lower()
print("Lowercase text:", lowercase_text)
# Out:
# Lowercase text: artificial intelligence is the simulation of human intelligence processes by machines, especially computer systems.
# it is used in healthcare, education, and transportatiion.
# nlp help machine understand human language.
